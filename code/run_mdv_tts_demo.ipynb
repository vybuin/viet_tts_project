# %% [markdown]
# # 🇻🇳 MDV-TTS Demo Launcher
#
# Launch the Multi-Dialect Vietnamese TTS Gradio interface.
#
# **Steps:**
# 1. Mount Google Drive
# 2. Install F5-TTS
# 3. Launch the Gradio demo (generates a public link)

# %% [markdown]
# ## 1. Mount Drive & Install

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/mdv-tts/F5-TTS
# !pip install -e . -q
# Out:
# /content/drive/MyDrive/mdv-tts/F5-TTS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 71.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 12.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 MB 17.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 12.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2. Configuration (Optional)
#
# Override defaults via environment variables if needed.
# Skip this cell to use the defaults baked into `mdv_tts_app.py`.

# %%
import os

# Uncomment and edit to override:
# os.environ['MDV_CHECKPOINT'] = '/content/drive/MyDrive/mdv-tts/F5-TTS/ckpts/viet/model_40000.safetensors'
# os.environ['MDV_VOCAB']      = '/content/drive/MyDrive/mdv-tts/F5-TTS/data/Emilia_ZH_EN_pinyin/vocab.txt'

print('Checkpoint:', os.environ.get('MDV_CHECKPOINT', '(using default)'))
print('Vocab:     ', os.environ.get('MDV_VOCAB', '(using default)'))
# Out:
# Checkpoint: (using default)
# Vocab:      (using default)

# %% [markdown]
# ## 3. Launch the Demo
#
# This will start the Gradio app and print a **public URL** you can share.
#
# > The model loads on the first generation request, so the first click takes a bit longer.

# %%
# %run /content/drive/MyDrive/mdv-tts/mdv_tts_app.py
# Out:
# [MDV-TTS] Loading checkpoint: /content/drive/MyDrive/mdv-tts/F5-TTS/ckpts/viet/model_40000.safetensors
# [MDV-TTS] Vocab file:         /content/drive/MyDrive/mdv-tts/F5-TTS/data/Emilia_ZH_EN_pinyin/vocab.txt
# Download Vocos from huggingface charactr/vocos-mel-24khz
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.yaml:   0%|          | 0.00/461 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/54.4M [00:00<?, ?B/s]
# vocab :  /content/drive/MyDrive/mdv-tts/F5-TTS/data/Emilia_ZH_EN_pinyin/vocab.txt
# token :  custom
# ...
